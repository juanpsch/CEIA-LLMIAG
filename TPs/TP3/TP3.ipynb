# %%
from diffusers import AutoPipelineForText2Image
import torch

pipeline = AutoPipelineForText2Image.from_pretrained("stabilityai/sdxl-turbo", torch_dtype=torch.float16, variant="fp16")
pipeline = pipeline.to("cuda")
# Out:
# Loading pipeline components...: 100%|██████████| 7/7 [00:00<00:00, 10.80it/s]

# %%
prompt = "A goat eating a hamburger near the Eiffel Tower in a sunny day. "
prompt = prompt + "Two 19th century police officers sharing a beer."
print(prompt)

pipeline_text2image = AutoPipelineForText2Image.from_pretrained("stabilityai/sdxl-turbo", torch_dtype=torch.float16, variant="fp16")
pipeline_text2image = pipeline_text2image.to("cuda")

image = pipeline_text2image(prompt=prompt, guidance_scale=0.0, num_inference_steps=1).images[0]
image
# Out:
# A goat eating a hamburger near the Eiffel Tower in a sunny day. Two 19th century police officers sharing a beer.
# Loading pipeline components...: 100%|██████████| 7/7 [00:00<00:00, 11.09it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.23it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
